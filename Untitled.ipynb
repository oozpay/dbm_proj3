# %%
import os
import pyspark

# 1. Clear broken background environment variables
os.environ.pop("PYSPARK_SUBMIT_ARGS", None)

# 2. Detect your PySpark version to ensure perfect compatibility
spark_version = pyspark.__version__
is_spark4 = spark_version.startswith("4")

# 3. Bundle Iceberg + AWS + Kafka packages together
if is_spark4:
    working_packages = (
        "org.apache.iceberg:iceberg-spark-runtime-4.0_2.13:1.10.0,"
        "org.apache.iceberg:iceberg-aws-bundle:1.10.0,"
        f"org.apache.spark:spark-sql-kafka-0-10_2.13:{spark_version}"
    )
else:
    working_packages = (
        "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.0,"
        "org.apache.iceberg:iceberg-aws-bundle:1.5.0,"
        f"org.apache.spark:spark-sql-kafka-0-10_2.12:{spark_version}"
    )

# 4. Start the session
from pyspark.sql import SparkSession

spark = SparkSession.builder \
  .appName("CDC-Bronze") \
  .config("spark.jars.packages", working_packages) \
  .config("spark.sql.catalog.lakehouse", "org.apache.iceberg.spark.SparkCatalog") \
  .config("spark.sql.catalog.lakehouse.type", "rest") \
  .config("spark.sql.catalog.lakehouse.uri", "http://iceberg-rest:8181") \
  .config("spark.sql.catalog.lakehouse.io-impl", "org.apache.iceberg.aws.s3.S3FileIO") \
  .config("spark.sql.catalog.lakehouse.s3.endpoint", "http://minio:9000") \
  .config("spark.sql.catalog.lakehouse.s3.path-style-access", "true") \
  .config("spark.sql.defaultCatalog", "lakehouse") \
  .getOrCreate()

spark.sql("CREATE NAMESPACE IF NOT EXISTS lakehouse.cdc")
print(f"Success! Spark {spark_version} loaded with Iceberg and Kafka.")
# Out:
# Success! Spark 4.1.0 loaded with Iceberg and Kafka.

# %%
raw = spark.read \
  .format("kafka") \
  .option("kafka.bootstrap.servers", "kafka:9092") \
  .option("subscribe", "dbserver1.public.customers") \
  .option("startingOffsets", "earliest") \
  .load()

# To verify it worked, run this in the next cell:
raw.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
from pyspark.sql import functions as F

# Filter out tombstone records (null value) first
raw_filtered = raw.filter(F.col("value").isNotNull())

bronze_df = raw_filtered.select(
  F.col("topic"),
  F.col("partition").alias("kafka_partition"),
  F.col("offset").alias("kafka_offset"),
  F.col("timestamp").alias("kafka_timestamp"),
  F.get_json_object(F.col("value").cast("string"), "$.payload.op").alias("op"),
  F.get_json_object(F.col("value").cast("string"), "$.payload.ts_ms").cast("long").alias("ts_ms"),
  F.get_json_object(F.col("value").cast("string"), "$.payload.after.id").cast("int").alias("after_id"),
  F.get_json_object(F.col("value").cast("string"), "$.payload.after.name").alias("after_name"),
  F.get_json_object(F.col("value").cast("string"), "$.payload.after.email").alias("after_email"),
  F.get_json_object(F.col("value").cast("string"), "$.payload.after.country").alias("after_country"),
  F.get_json_object(F.col("value").cast("string"), "$.payload.before.id").cast("int").alias("before_id"),
)

bronze_df.writeTo("lakehouse.cdc.bronze_customers").createOrReplace()

# %%
spark.sql("SELECT count(*) FROM lakehouse.cdc.bronze_customers").show()
spark.sql("""
  SELECT op, after_id, after_name, after_email, ts_ms
  FROM lakehouse.cdc.bronze_customers LIMIT 5
""").show(truncate=False)
# Out:
# +--------+
# |count(1)|
# +--------+
# |      18|
# +--------+
#
# +---+--------+--------------+-------------------------+-------------+
# |op |after_id|after_name    |after_email              |ts_ms        |
# +---+--------+--------------+-------------------------+-------------+
# |r  |9       |Ingrid Larsen |ingrid@example.com       |1776346586734|
# |r  |13      |Mia Ozols     |mia.ozols@inbox.org      |1776346586736|
# |r  |4       |David Jonaitis|david@example.com        |1776346586736|
# |r  |8       |Hiro Tanaka   |updated_8_136@example.com|1776346586736|
# |r  |6       |Frank Muller  |updated_6_803@mail.com   |1776346586736|
# +---+--------+--------------+-------------------------+-------------+

# %%
spark.sql("""
  CREATE TABLE IF NOT EXISTS lakehouse.cdc.silver_customers (
    id INT, name STRING, email STRING, country STRING, last_updated_ms BIGINT
  ) USING iceberg
""")
# Out:
# DataFrame[]

# %%
from pyspark.sql.window import Window

# Use COALESCE because for deletes, after_id is null but before_id has the key
bronze_with_key = bronze_df.withColumn(
  "entity_id", F.coalesce(F.col("after_id"), F.col("before_id"))
)

w = Window.partitionBy("entity_id").orderBy(F.col("ts_ms").desc())
deduped = bronze_with_key \
  .filter(F.col("op").isNotNull()) \
  .withColumn("rn", F.row_number().over(w)) \
  .filter("rn = 1").drop("rn")

# %%
deduped.createOrReplaceTempView("cdc_batch")

spark.sql("""
  MERGE INTO lakehouse.cdc.silver_customers AS t
  USING cdc_batch AS s
  ON t.id = s.entity_id
  
  WHEN MATCHED AND s.op = 'd' THEN DELETE
  
  WHEN MATCHED AND s.op IN ('c','u','r') THEN UPDATE SET
    t.name = s.after_name, t.email = s.after_email,
    t.country = s.after_country, t.last_updated_ms = s.ts_ms

  WHEN NOT MATCHED AND s.op != 'd' THEN INSERT
    (id, name, email, country, last_updated_ms)
    VALUES (s.after_id, s.after_name, s.after_email, s.after_country, s.ts_ms)

""")
# Out:
# DataFrame[]

# %%
spark.sql("SELECT count(*) FROM lakehouse.cdc.silver_customers").show()
spark.sql("SELECT * FROM lakehouse.cdc.silver_customers ORDER BY id LIMIT 5").show(truncate=False)
# Out:
# +--------+
# |count(1)|
# +--------+
# |      18|
# +--------+
#
# +---+--------------+--------------------------+-----------+---------------+
# |id |name          |email                     |country    |last_updated_ms|
# +---+--------------+--------------------------+-----------+---------------+
# |4  |David Jonaitis|david@example.com         |Poland     |1776346586736  |
# |6  |Frank Muller  |updated_6_803@mail.com    |Germany    |1776346586736  |
# |8  |Hiro Tanaka   |updated_8_136@example.com |Japan      |1776346586736  |
# |9  |Ingrid Larsen |ingrid@example.com        |Norway     |1776346586734  |
# |11 |Zara Andersen |updated_11_947@example.com|South Korea|1776346586738  |
# +---+--------------+--------------------------+-----------+---------------+

# %%
#Murad cont from here
import psycopg2

def pg_execute(sql, fetch=False):
    conn = psycopg2.connect(
        host="postgres",
        port=5432,
        dbname="sourcedb",
        user="cdc_user",
        password="admin",
    )
    try:
        with conn.cursor() as cur:
            cur.execute(sql)
            if fetch:
                return cur.fetchall()
            conn.commit()
    finally:
        conn.close()

# %%
pg_execute("SELECT count(*) FROM customers;", fetch=True)
pg_execute("SELECT count(*) FROM drivers;", fetch=True)

spark.sql("SELECT count(*) FROM lakehouse.cdc.silver_customers").show()
spark.sql("SELECT count(*) FROM lakehouse.cdc.silver_drivers").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |      43|
# +--------+
#
# +--------+
# |count(1)|
# +--------+
# |      18|
# +--------+

# %%
spark.sql("""
SELECT id, name, rating, city, active, is_deleted
FROM lakehouse.cdc.silver_drivers
ORDER BY id
LIMIT 10
""").show()
# Out:
# +---+---------------+------+-------------+------+----------+
# | id|           name|rating|         city|active|is_deleted|
# +---+---------------+------+-------------+------+----------+
# | 16|      Raj Ozols|  3.99|        Bronx|  true|     false|
# | 17|    Sofia Smith|  4.83|     Brooklyn|  true|     false|
# | 19|    Lucas Ozols|  4.03|Staten Island| false|     false|
# | 22|    Luna Larsen|  3.93|Staten Island| false|     false|
# | 24|   Oscar Garcia|  3.87|Staten Island|  true|     false|
# | 26|     Chen Ozols|  3.67|       Queens| false|     false|
# | 28|  Emma Nakamura|  3.94|     Brooklyn|  true|     false|
# | 31|Olivia Virtanen|  3.88|        Bronx| false|     false|
# | 34|     Mateo Park|  4.19|       Queens|  true|     false|
# | 35|     Kai Petrov|  4.62|Staten Island| false|     false|
# +---+---------------+------+-------------+------+----------+

# %%
#REPORT STUFF
# Best fare-per-mile driver
spark.sql("""
SELECT driver_id, driver_name, current_rating, avg_fare_per_mile
FROM lakehouse.gold.gold_assignment_efficiency
ORDER BY avg_fare_per_mile DESC
LIMIT 1;
""").show()
# Out:
# +---------+-----------+--------------+-----------------+
# |driver_id|driver_name|current_rating|avg_fare_per_mile|
# +---------+-----------+--------------+-----------------+
# |       17|Sofia Smith|          4.83|            10.44|
# +---------+-----------+--------------+-----------------+

# %%
# workload balance
spark.sql("""
SELECT *
FROM lakehouse.gold.gold_workload_balance;
""").show()
# Out:
# +---------------------------+----------------+----------------+----------------+---------------------+----------------------------+
# |stddev_trips_across_drivers|max_driver_trips|min_driver_trips|avg_driver_trips|max_to_min_trip_ratio|drivers_more_than_2x_average|
# +---------------------------+----------------+----------------+----------------+---------------------+----------------------------+
# |                       1.42|              59|              53|           56.83|                 1.11|                          []|
# +---------------------------+----------------+----------------+----------------+---------------------+----------------------------+

# %%
# efficiency

# %%
spark.sql("""
SELECT *
FROM lakehouse.gold.gold_assignment_efficiency
ORDER BY trips_assigned DESC
LIMIT 10;
""").show()
# Out:
# +---------+---------------+--------------+-------------+---------+--------------+--------------+-------------+-----------------+---------------------------+
# |driver_id|    driver_name|current_rating|         city|is_active|trips_assigned|total_distance|total_revenue|avg_fare_per_mile|estimated_idle_time_minutes|
# +---------+---------------+--------------+-------------+---------+--------------+--------------+-------------+-----------------+---------------------------+
# |       19|    Lucas Ozols|          4.03|Staten Island|    false|            59|        177.52|      1464.16|             8.25|                        0.0|
# |       35|     Kai Petrov|          4.62|Staten Island|    false|            58|         168.3|      1535.15|             9.12|                       0.47|
# |       31|Olivia Virtanen|          3.88|        Bronx|    false|            58|        158.26|      1484.84|             9.38|                        0.0|
# |       38|     Zara Silva|          4.66|        Bronx|     true|            58|        138.88|      1430.09|             10.3|                        0.0|
# |       41|     Ella Silva|          4.47|       Queens|     true|            58|        160.03|      1455.07|             9.09|                      22.52|
# |       22|    Luna Larsen|          3.93|Staten Island|    false|            58|        142.27|      1334.14|             9.38|                       0.13|
# |       17|    Sofia Smith|          4.83|     Brooklyn|     true|            58|        118.71|      1239.02|            10.44|                        0.0|
# |       28|  Emma Nakamura|          3.94|     Brooklyn|     true|            57|        128.12|       1308.1|            10.21|                        0.0|
# |       16|      Raj Ozols|          3.99|        Bronx|     true|            57|        155.18|      1396.17|              9.0|                        2.8|
# |       36|     Luna Novak|          4.24|       Queens|     true|            57|        180.76|      1575.47|             8.72|                        0.0|
# +---------+---------------+--------------+-------------+---------+--------------+--------------+-------------+-----------------+---------------------------+

# %%
#remember to kill simulate.py first 
print(pg_execute("SELECT COUNT(*) FROM drivers;", fetch=True))
print(pg_execute("SELECT COUNT(*) FROM customers;", fetch=True))
#drivers dont match here because we are keeping deleted drives check drivers select and is_deleted select below counts match
spark.sql("SELECT COUNT(*) AS silver_drivers FROM lakehouse.cdc.silver_drivers").show()
spark.sql("SELECT COUNT(*) AS silver_customers FROM lakehouse.cdc.silver_customers").show()
# Out:
# [(203,)]
# [(497,)]
# +--------------+
# |silver_drivers|
# +--------------+
# |           242|
# +--------------+
#
# +----------------+
# |silver_customers|
# +----------------+
# |             497|
# +----------------+

# %%
print(pg_execute("SELECT * FROM drivers WHERE id = 17;", fetch=True))

spark.sql("""
SELECT *
FROM lakehouse.cdc.silver_drivers
WHERE id = 17
""").show(truncate=False)
# Out:
# []
# +---+-----------+--------------+------+--------+------+----------------+----------+-------+---------------+
# |id |name       |license_number|rating|city    |active|created_at      |is_deleted|last_op|last_updated_ms|
# +---+-----------+--------------+------+--------+------+----------------+----------+-------+---------------+
# |17 |Sofia Smith|TLC-99323     |4.83  |Brooklyn|false |1777815923995395|true      |d      |1777816248114  |
# +---+-----------+--------------+------+--------+------+----------------+----------+-------+---------------+

# %%
spark.sql("""
SELECT COUNT(*) AS active_silver_drivers
FROM lakehouse.cdc.silver_drivers
WHERE is_deleted = false
""").show()
# Out:
# +---------------------+
# |active_silver_drivers|
# +---------------------+
# |                  203|
# +---------------------+

# %%
spark.sql("""SELECT * FROM lakehouse.cdc.silver_drivers.snapshots;""").show()
# Out:
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+
# |        committed_at|        snapshot_id|          parent_id|operation|       manifest_list|             summary|
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+
# |2026-05-03 14:12:...|3266480515663227637|               NULL|   append|s3://warehouse/cd...|{spark.app.id -> ...|
# |2026-05-03 15:29:...|6805734495028186296|3266480515663227637|overwrite|s3://warehouse/cd...|{spark.app.id -> ...|
# |2026-05-03 15:33:...|7807839544676908070|6805734495028186296|overwrite|s3://warehouse/cd...|{spark.app.id -> ...|
# |2026-05-03 15:34:...|5935298304820774096|7807839544676908070|overwrite|s3://warehouse/cd...|{spark.app.id -> ...|
# |2026-05-03 15:37:...|3443252409102594301|5935298304820774096|overwrite|s3://warehouse/cd...|{spark.app.id -> ...|
# +--------------------+-------------------+-------------------+---------+--------------------+--------------------+

# %%
spark.sql("""
SELECT *
FROM lakehouse.taxi.gold_hourly_zone
ORDER BY pickup_hour, trip_count DESC
LIMIT 20
""").show(truncate=False)
# Out:
# +-------------------+--------------+-----------------------------+----------+--------+------------+-------------+
# |pickup_hour        |pickup_borough|pickup_zone                  |trip_count|avg_fare|avg_distance|total_revenue|
# +-------------------+--------------+-----------------------------+----------+--------+------------+-------------+
# |2024-12-31 23:00:00|Manhattan     |East Chelsea                 |1         |14.9    |2.28        |23.88        |
# |2024-12-31 23:00:00|Manhattan     |Central Park                 |1         |10.7    |1.03        |15.7         |
# |2024-12-31 23:00:00|Manhattan     |Sutton Place/Turtle Bay North|1         |19.1    |3.95        |24.1         |
# |2024-12-31 23:00:00|Manhattan     |West Chelsea/Hudson Yards    |1         |16.3    |3.0         |26.62        |
# |2025-01-01 00:00:00|Manhattan     |Upper East Side South        |66        |13.05   |1.99        |1360.53      |
# |2025-01-01 00:00:00|Manhattan     |East Village                 |57        |14.37   |2.23        |1261.55      |
# |2025-01-01 00:00:00|Manhattan     |Lincoln Square East          |56        |13.6    |1.88        |1235.91      |
# |2025-01-01 00:00:00|Manhattan     |Upper West Side South        |51        |13.62   |2.17        |1109.3       |
# |2025-01-01 00:00:00|Manhattan     |Yorkville West               |47        |12.43   |2.21        |971.19       |
# |2025-01-01 00:00:00|Manhattan     |Sutton Place/Turtle Bay North|44        |12.02   |1.81        |854.26       |
# |2025-01-01 00:00:00|Manhattan     |Lenox Hill West              |34        |12.61   |1.83        |693.96       |
# |2025-01-01 00:00:00|Manhattan     |Union Sq                     |31        |15.87   |2.25        |771.04       |
# |2025-01-01 00:00:00|Manhattan     |West Village                 |30        |19.4    |3.18        |829.74       |
# |2025-01-01 00:00:00|Manhattan     |Greenwich Village South      |30        |17.12   |2.15        |789.66       |
# |2025-01-01 00:00:00|Manhattan     |Lenox Hill East              |29        |12.0    |2.07        |561.09       |
# |2025-01-01 00:00:00|Manhattan     |Upper East Side North        |29        |14.92   |2.46        |664.41       |
# |2025-01-01 00:00:00|Manhattan     |Gramercy                     |28        |15.28   |2.44        |685.01       |
# |2025-01-01 00:00:00|Manhattan     |Flatiron                     |25        |20.0    |3.02        |775.16       |
# |2025-01-01 00:00:00|Manhattan     |Midtown East                 |25        |14.37   |2.12        |539.34       |
# |2025-01-01 00:00:00|Manhattan     |Upper West Side North        |25        |12.69   |1.86        |501.88       |
# +-------------------+--------------+-----------------------------+----------+--------+------------+-------------+

# %%
spark.sql("SELECT COUNT(*) AS bronze_taxi_rows FROM lakehouse.taxi.bronze_taxi").show()
spark.sql("SELECT COUNT(*) AS silver_taxi_rows FROM lakehouse.taxi.silver_taxi").show()
spark.sql("SELECT COUNT(*) AS gold_taxi_rows FROM lakehouse.taxi.gold_hourly_zone").show()
# Out:
# +----------------+
# |bronze_taxi_rows|
# +----------------+
# |            1047|
# +----------------+
#
# +----------------+
# |silver_taxi_rows|
# +----------------+
# |            1023|
# +----------------+
#
# +--------------+
# |gold_taxi_rows|
# +--------------+
# |            72|
# +--------------+
